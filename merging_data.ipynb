# %%
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("Crimes_jan18_to_present.csv"))
community_areas = pd.read_csv(os.path.join("community_areas.csv"))

# %%
df.head()
# Out:
#          ID Case_Number           Date                  Block IUCR  \
# 0     24026    JB322801  6/25/18 23:50       123XX S YALE AVE  110
# 1     24024    JB321259   6/25/18 0:03    044XX S PRAIRIE AVE  110
# 2  11366605    JB331566  6/13/18 20:30  075XX S LAFAYETTE AVE  910
# 3  11366591    JB331560   5/8/18 20:00    014XX N AUSTIN BLVD  890
# 4  11366513    JB327920  5/25/18 12:00         0000X W M15 ST  810
#
#           Primary_Type          Description            Location_Description  \
# 0             HOMICIDE  FIRST DEGREE MURDER                          STREET
# 1             HOMICIDE  FIRST DEGREE MURDER                          STREET
# 2  MOTOR VEHICLE THEFT           AUTOMOBILE                          STREET
# 3                THEFT        FROM BUILDING                       RESIDENCE
# 4                THEFT            OVER $500  AIRPORT EXTERIOR - SECURE AREA
#
#    Arrest  Domestic              ...               Ward  Community_Area  \
# ...

# %%
community_areas.head()
# Out:
#    Community_Area Community_Area_Name
# 0               1         Rogers Park
# 1               2          West Ridge
# 2               3              Uptown
# 3               4      Lincoln Square
# 4               5        North Center

# %%
community_areas.head()

# %%
combo_data=pd.merge(df, community_areas, on="Community_Area")
combo_data.head()
# Out:
#          ID Case_Number           Date                Block  IUCR  \
# 0     24026    JB322801  6/25/18 23:50     123XX S YALE AVE   110
# 1  11359886    JB322747  6/25/18 22:04   001XX W BRAYTON ST   486
# 2  11359755    JB322421  6/25/18 17:28  122XX S PARNELL AVE   460
# 3  11359650    JB322719  6/25/18 21:57     002XX W 119TH ST  2027
# 4  11359309    JB322038  6/25/18 14:24   122XX S NORMAL AVE  051A
#
#   Primary_Type              Description Location_Description  Arrest  \
# 0     HOMICIDE      FIRST DEGREE MURDER               STREET   False
# 1      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 2      BATTERY                   SIMPLE             SIDEWALK   False
# 3    NARCOTICS              POSS: CRACK             SIDEWALK    True
# 4      ASSAULT      AGGRAVATED: HANDGUN        PARK PROPERTY   False
#
#    Domestic         ...           Community_Area  FBI_Code  X_Coordinate  \
# 0     False         ...                       53       01A     1176840.0
# ...

# %%
##exporting combo data
combo_data.to_csv("combo_crime_data.csv", index=False, header =True)
